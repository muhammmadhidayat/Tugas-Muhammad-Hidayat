# %%
import pandas as pd
import json
data_json = [
    {"ID": 121, "Nama": "robert", "Usia": 25, "Pekerjaan": "Data Scientist"},
    {"ID": 312, "Nama": "Budi", "Usia": 29, "Pekerjaan": "Analyst"},
    {"ID": 311, "Nama": "yaitu", "Usia": 22, "Pekerjaan": "Engineer"}
]
print(json.dumps(data_json, indent=4))
data = data_json
with open("data.json", "w") as file: json.dump(data, file, indent=4)
df = pd.DataFrame(data)
df.to_csv("data_diri.csv", index=False)
# Out:
# [
#     {
#         "ID": 121,
#         "Nama": "robert",
#         "Usia": 25,
#         "Pekerjaan": "Data Scientist"
#     },
#     {
#         "ID": 312,
#         "Nama": "Budi",
#         "Usia": 29,
#         "Pekerjaan": "Analyst"
#     },
#     {
#         "ID": 311,
#         "Nama": "yaitu",
#         "Usia": 22,
#         "Pekerjaan": "Engineer"
#     }
# ]

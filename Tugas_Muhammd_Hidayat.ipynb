# %%
import pandas as pd
df = pd.read_csv('/content/character.csv')

# %%
data = pd.read_csv("character.csv")
print (data)
# Out:
#   Original Name              English Name  Gender      Age    Birth Date  \
# 0       野原しんのすけ  Shinnosuke 'Shin' Nohara    Male        5       July 22
# 1         野原みさえ              Misae Nohara  Female       29    October 10
# 2         野原ひろし            Hiroshi Nohara    Male       35      April 16
# 3        野原ひまわり           Himawari Nohara  Female        0  September 27
# 4          風間くん               Toru Kazama    Male        5       June 28
# 5          桜田ネネ             Nene Sakurada  Female        5        June 5
# 6         佐藤マサオ                 Maso Sato    Male        5   November 30
# 7         ボーちゃん                 Bo Suzuki    Male        5     August 20
# 8          園長先生           Principal Enoki    Male       52         May 6
# 9       アクション仮面              Action Kamen    Male  Unknown       Unknown
#
#       First Appearance              Role              Occupation  \
# 0  Manga Vol. 1 (1990)       Protagonist    Kindergarten Student
# ...

# %%
data.head()
# Out:
#   Original Name              English Name  Gender Age    Birth Date  \
# 0       野原しんのすけ  Shinnosuke 'Shin' Nohara    Male   5       July 22
# 1         野原みさえ              Misae Nohara  Female  29    October 10
# 2         野原ひろし            Hiroshi Nohara    Male  35      April 16
# 3        野原ひまわり           Himawari Nohara  Female   0  September 27
# 4          風間くん               Toru Kazama    Male   5       June 28
#
#       First Appearance         Role            Occupation  \
# 0  Manga Vol. 1 (1990)  Protagonist  Kindergarten Student
# 1         Manga Vol. 1       Mother             Housewife
# 2         Manga Vol. 1       Father             Salaryman
# 3     Episode 1 (1992)  Baby sister                Infant
# 4         Manga Vol. 1       Friend  Kindergarten Student
#
#               Personality                                 Likes  \
# 0  Mischievous, energetic  Anpan, action shows, beautiful women
# 1       Strict but loving                   Sales, saving money
# ...

# %% [markdown]
# **data.head**:
#
# Dataset terdiri dari 19 variabel dengan mayoritas bertipe data object (kategorikal), serta satu variabel numerik yaitu Age. Output data.head() menampilkan 5 observasi pertama sebagai gambaran awal struktur dan isi dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Original Name       10 non-null     object
#  1   English Name        10 non-null     object
#  2   Gender              10 non-null     object
#  3   Age                 10 non-null     object
#  4   Birth Date          10 non-null     object
#  5   First Appearance    10 non-null     object
#  6   Role                10 non-null     object
#  7   Occupation          10 non-null     object
#  8   Personality         10 non-null     object
#  9   Likes               10 non-null     object
#  10  Dislikes            10 non-null     object
#  11  Best Friends        8 non-null      object
#  12  Rivals              8 non-null      object
#  13  Family Members      9 non-null      object
#  14  Voice Actor (JP)    10 non-null     object
# ...

# %% [markdown]
# **data.info**:
#
# Dataset memiliki 10 baris dan 19 kolom
#
# Semua kolom bertipe object (data teks)
#
# Tidak terdapat missing value
#
# Dataset bersifat deskriptif/kategorikal

# %%
data.shape
# Out:
# (10, 19)

# %% [markdown]
# **data.shape**:
#
# 10 baris (data karakter)
#
# 19 kolom (atribut karakter)
#
# Seluruh kolom bertipe data object (teks/kategorikal)
#
# Dataset ini termasuk dataset deskriptif/kategorikal dan tidak memiliki variabel numerik.
